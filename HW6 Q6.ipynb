# %% [markdown]
# # The Problem
#
# ![hall.png](attachment:hall.png)
#
# An experiment was carried out to determine the electrical properties of a new conducting material. A bar was made out of the material, 𝐿=
#  18 cm long with a rectangular cross section ℎ=
#  5 cm high and 𝑤=
#  0.8 cm deep. The bar was part of a circuit and carried a steady current (the diagram shows only part of the circuit). A uniform magnetic field of 1.8 tesla was applied perpendicular to the bar, coming out of the page (using some coils that are not shown). Two voltmeters were connected along and across the bar as shown. The reading on Voltmeter 1 is $Δ𝑉1= - 0.45$ volt. The reading on Voltmeter 2 is $Δ𝑉2= +0.00028$ volt. The connections across the bar for Voltmeter 2 were carefully placed directly across from each other to eliminate false readings corresponding to the much larger voltage along the bar. There is only one kind of mobile charge in this material.
#
# ## Part 1
# What is the sign of the mobile charges, and which way do they move?
#
# Remember that a voltmeter gives a positive reading if the positive lead is connected to a higher potential location than the negative lead.
#
# ## Part 2
#
# What is the drift speed 𝑣
#  of the mobile charges?
#
# ## Part 3
# What is the mobility 𝑢
#  of the mobile charges?
#
# ## Part 4
# The current running through the bar was measured to be 0.4 ampere. If each mobile charge is singly charged (|𝑞|=𝑒
# ), how many mobile charges are there in 1 $m^3$ of this material?
#
# ## Part 5
# What is the resistance in ohms of this length of bar?

# %% [markdown]
# # Part 1 Solution
#
# The question is, What is the sign of the mobile charges, and which way do they move?
#
# To answer this question, what we really need is to determine what the charge distribution looks like on the bar.  Unfortunately, they don't directly give us this information.  Instead, they tell us the sign of the voltage.  So first we need to use that information to determine where the charge is on the bar, and then we can figure out what the sign of the mobile charges is and what direction they're moving.
#
# ## Charge distribution on the bar
#
# $\Delta V2$ is positive, and the book gives us a hint: <mark>Remember that a voltmeter gives a positive reading if the positive lead is connected to a higher potential location than the negative lead.</mark>.  I prefer to think of a voltmeter as telling us the direction of the electric field.  The negative lead (black) is the start of the path, and the positive lead (red) is the end of the path.  Because $\Delta V = -\int\vec{E}\cdot\vec{dl}$, if the path goes against the electric field, the voltage will be positive and if the path goes with the electric field, the voltage will be negative.  So in the case of $\Delta V2$, that means the electric field must be pointing up, which means there must be positive charge along the bottom of the bar and negative charge on the top,
#
# $\Delta V1$ is also telling us the direction of the electric field, this time along the bar.  Because $\Delta V1$ is negative, the electric field must point along the path - to the right.
#
# ![hall_charge.svg](attachment:hall_charge.svg)
#
# ## Now we know the direction of the electric fields
#
# So now we know the electric has a component to the right that drives the charges across the bar and component upwards that's formed as the charge accumulated on the top and bottom of the bar.  Because $\vec{F} = q\vec{E}$, the component to the right tells us that we either have positive charges moving to the right or negative charges moving to the left.
#
# Let's consider each of these, and see which one will result in positive charges accumulating on the bottom of the bar.
#
# ## Is it negative charges moving to the left?
#
# For negative charges moving to the left the picture looks like:
#
# ![hall_negative.png](images/hall_negative.png)
#
# We can use $\vec{F} = q\vec{v}\times\vec{B}$ to determine the force on the negative charges due to the magnetic field, and see if they end up being pushed upwards.  We have that $q$ is $-e$, the charge of the electron.  Looking at this image, we see that $\vec{v} = \langle -v, 0, 0\rangle$.  The magnetic field $B$ is represented with a dot, which means it's coming out of the page, or $\vec{B} = \langle 0, 0, B\rangle$.  Now we can use these values to calculate the direction of the force.

# %%
# sympy is a python library that allows symbolic manipulation
# similar to Mathematica or symbolab
# In my opinion, Mathematica documentation is outstanding,
# so if you want symbolic manipulation and have Mathematica installed,
# use Mathematica!
# Here I'll use sympy so we can see the result in our notebook.
import sympy as s

e, v, B = s.symbols("e, v, B")
v_vec = s.Matrix([-v, 0, 0])
B_vec = s.Matrix([0, 0, B])

Force_vec = -e*v_vec.cross(B_vec)

# The result is a vector that points downward
print (Force_vec)
# Out:
# Matrix([[0], [-B*e*v], [0]])

# %% [markdown]
# Since the force on the negative charges is downward, these negative charges would get pushed to the bottom of the bar.  But that's not what we see from the voltage - we instead see positive charges on the bottom.  So this isn't the right answer.
#
# We only have two options - negative charges moving to the left or positive charges moving to the right.  So the answer must be positive charges moving to the right.  Let's look at that diagram and confirm that the positive charges would in fact be pushed to the bottom as expected.
#
# ## Is it positive charges moving to the right?
#
# For positive charges moving to the right the picture looks like:
#
# ![hall_positive.png](images/hall_positive.png)
#
# We can use $\vec{F} = q\vec{v}\times\vec{B}$ to determine the force on the negative charges due to the magnetic field, and see if they end up being pushed upwards.  We have that $q$ is $+e$, opposite the charge of the electron (solid state physicists call these "holes").  Looking at this image, we see that $\vec{v} = \langle v, 0, 0\rangle$.  The magnetic field $B$ is represented with a dot, which means it's coming out of the page, or $\vec{B} = \langle 0, 0, B\rangle$.  Now we can use these values to calculate the direction of the force.

# %%
import sympy as s

e, v, B = s.symbols("e, v, B")
v_vec = s.Matrix([v, 0, 0])
B_vec = s.Matrix([0, 0, B])

Force_vec = e*v_vec.cross(B_vec)

# The result is a vector that points downward
print (Force_vec)
# Out:
# Matrix([[0], [-B*e*v], [0]])

# %% [markdown]
# The positive charges would feel a downward force, and get pushed to the bottom!  That's what we think the charge distribution looks like, so that's the answer!  Hooray!

# %% [markdown]
# # Part 2 Solution
#
# The question here is, "What is the drift speed 𝑣
#  of the mobile charges?"
#
# We can find this because when the bar has reached its equilibrium state, the electric and magnetic forces in the y direction must balance.  This will mean that no more charge accumulates on the top and bottom of the bar.  In other words,
#
# $F_{electric, y} + F_{magnetic, y} = 0$
#
# Or
#
# $qE_y - eBv = eE_y -e B v = 0$
#
# And that lets us solve for the velocity $v$, $v = \frac{E_y}{B}$.
#
# We're given $B$, but what about $E_y$?  $E_y$ comes from one of the voltages - is it $\Delta V1$ or $\Delta V2$?
#
# So the question is, which voltage is sensitive to $E_y$?  Let's recall what the paths are for each of the voltages:
#
# ![hall_voltage.svg](attachment:hall_voltage.svg)
#
# We want to figure out which voltage, $\Delta V1$ or $\Delta V2$, gives us information about $E_y$.  Let's check each of them.
#
# $\Delta V1 = -\int_{A_1}^{B_1} \vec{E}\cdot\vec{dl} = -\int_{A_1}^{B_1} \langle E_x, E_y, 0\rangle\cdot\langle dx, dy, dz \rangle = -\int_{A_1}^{B_1} E_x dx + E_y dy $
# $ = -\int_0^L E_x dx -\int_h^h E_y dy = -E_x\int_0^L dx -E_y\int_h^h dy = -E_x x|_0^L - E_y y|_h^h = -E_x (L - 0) - E_y (h-h) = -E_xL$
#
# So $\Delta V1$ gives us information about $E_x$.  We're looking for information about $E_y$.  Let's try $\Delta V2$.  Can you do the same setup as above and calculate it?
#
# $\Delta V2 = -\int_{A_2}^{B_2} \vec{E}\cdot\vec{dl} = -\int_{A_2}^{B_2} \langle E_x, E_y, 0\rangle\cdot\langle dx, dy, dz \rangle = -\int_{A_2}^{B_2} E_x dx + E_y dy $
# $ = -\int_L^L E_x dx -\int_h^0 E_y dy = -E_x\int_L^L dx -E_y\int_0^h dy = -E_x x|_L^L - E_y y|_h^0 = -E_x (L - L) - E_y (0-h) = E_yh$
#
# So $E_y = \frac{\Delta V2}{h}$ and now we can plug this into our equation for the velocity: $v = \frac{E_y}{B} = \frac{\Delta V2}{Bh}$.

# %%
# the values given in the problem
# are different than the values below.
# can you update the code with the correct values?
V2 = 0.00025
B = 1.4
h = 5E-2

v = V2/(B*h)

print (v)
# Out:
# 0.0035714285714285718

# %% [markdown]
# ## Part 3 Answer
# What is the mobility 𝑢
#  of the mobile charges?
#
# Section 14.6 of the Matter and Interactions book explains that $v_{drift} = uE$, where $v_{drift}$ is the drift velocity, $E$ is the electric field, and $u$ is the mobility.  Notice that the units of mobility are the units of the electric field divided by a velocity, $(m/s)/(N/C)$.
#
# The velocity is purely in the x direction, so the electric field component that matters here is $E_x$.  Above we saw that $\Delta V1$ gives us information about $E_x$, $\Delta V1 = -E_xL$.
#
# So
#
# $u = \frac{v_{drift}}{E} = \frac{v_{drift}}{\Delta V1 / L}$

# %%
V1 = 0.45
L = 18E-2
mobility = v/(V1/L)

print (mobility)
# Out:
# 0.0014285714285714288

# %% [markdown]
# ## Part 4
# The current running through the bar was measured to be 0.4 ampere. If each mobile charge is singly charged (|𝑞|=𝑒
# ), how many mobile charges are there in 1 $m^3$ of this material?
#
# Section 17.5 of Matter and Interactions discusses current and charge carrier density and derives the equation
#
# $i = Anv_{drift}$, where $i$ is the number of electrons per second that pass through cross-sectional area $A$ of a wire, $n$ is the number of mobile electrons per unit volume, and $v_{drift}$ is the drift velocity we solved for above.
#
# The relationship between the macroscopic current (measured in Amps, or Coulombs/second) is $I = ei$, where $e$ is the charge of an electron.
#
# This problem is asking for $N$, the total number of electrons in the bar.  Its relationship to $n$ is $N = nV$, where $V$ is the volume of the bar and is $Lwh$.
#
# So now we can put this all together and get
#
# $\frac{I}{e} = A \frac{N}{V} v_{drift} = wh \frac{N}{1 m^3} v_{drift} = \frac{whN}{1 m^3} v_{drift}$
#
# and solve for N:
#
# $N = \frac{I1m^3}{ev_{drift}wh}$

# %%
# I need this for the charge of the electron
from scipy import constants

# the values below aren't correct
# and the value for the velocity isn't correct
# so you'll need to correct the values for the 
# velocity and correct the values below
# to get the correct value for N
current = 0.8
w = 0.8E-2
h = 5E-2
e = constants.elementary_charge

N = current*1/(e*v*w*h)

print (N)
# Out:
# 3.495245081698027e+24

# %% [markdown]
# ## Part 5 Solution
# What is the resistance in ohms of this length of bar?
#
# Here the appropriate equation is $\Delta V = IR$.  In Part 4 they tell us that the current is 0.4 Amps.  The current is flowing in the +x direction, driven by the $\Delta V1$ caused by the battery.  So we have $R = \Delta V1/I$.

# %%
V1 = 0.45
I = 0.4

R = V1/I

print (R)
# Out:
# 1.125
